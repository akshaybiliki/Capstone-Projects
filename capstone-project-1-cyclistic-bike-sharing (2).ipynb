# %% [markdown]
# ## Case Study 1: Cyclistic bike-share analysis

# %% [markdown]
# # **INTRODUCTION** :
#
# * A bike-share company in Chicago. The director of marketing believes the company’s future success depends on maximizing the number of annual memberships. Therefore,needs to understand how casual riders and annual members use Cyclistic bikes differently.
#
# * From these insights,  will design a new marketing strategy to convert casual riders into annual members.

# %% [markdown]
# # **ASK**
#
# * Buiesness Task : The company's mission is to convert casual riders into annual members to increase revenue
# * Key Stakeholders : 1.Lily Moreno -> The director of marketing and your manager
#                      2.Cyclistic marketing analytics team
#                      3.Cyclistic executive team
#
# # **PREPARE**
# * Data source : Link -> https://divvy-tripdata.s3.amazonaws.com/index.html. Here i selected 12 months data (Apr 2020 to Apr 2021)
# * Data credibility : Good condition.
# * ROCCC Analysis :  1.Reliability - Reliable
#                     2.Original - Yes
#                     3.Comprhensive : It is not 100% comprehensive as some information is missing
#                     4.Current - 12 months old
#                     5.Cited - Yes

# %% [markdown]
# # **PROCESS AND CLEAN**

# %%
# Helps  wrangle Data 
library(tidyverse)

# helps wrangle date and time
library(lubridate)

# get summary data
library(skimr)
library(janitor)
library(dplyr)
library(ggplot2)
library(readxl)
install.packages("xlsx")
library(xlsx)

# %%
Apr_20 <- read.csv ('../input/cyclistic-bike-share/202004-divvy-tripdata.csv')
May_20 <- read.csv('../input/cyclistic-bike-share/202005-divvy-tripdata.csv')
Jun_20 <- read.csv('../input/cyclistic-bike-share/202006-divvy-tripdata.csv')
July_20 <- read.csv ('../input/cyclistic-bike-share/202007-divvy-tripdata.csv')
Aug_20 <- read.csv('../input/cyclistic-bike-share/202008-divvy-tripdata.csv')
Sep_20 <- read.csv('../input/cyclistic-bike-share/202009-divvy-tripdata.csv')
Oct_20 <- read.csv('../input/cyclistic-bike-share/202010-divvy-tripdata.csv')
Nov_20 <- read.csv('../input/cyclistic-bike-share/202011-divvy-tripdata.csv')
Dec_20 <- read.csv('../input/cyclistic-bike-share/202012-divvy-tripdata.csv')
Jan_21 <- read.csv('../input/cyclistic-bike-share/202101-divvy-tripdata.csv')
Feb_21 <- read.csv('../input/cyclistic-bike-share/202102-divvy-tripdata.csv')
Mar_21 <- read.csv('../input/cyclistic-bike-share/202103-divvy-tripdata.csv')
Apr_21 <- read.csv('../input/cyclistic-bike-share/202104-divvy-tripdata.csv')

# %%
# Changing variables of "started_at" and "ended_at" from chr to Posixct 

Apr_20 <- mutate(Apr_20,started_at =as.POSIXct(Apr_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Apr_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
May_20 <- mutate(May_20,started_at =as.POSIXct(May_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(May_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Jun_20 <- mutate(Jun_20,started_at =as.POSIXct(Jun_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Jun_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
July_20 <- mutate(July_20,started_at =as.POSIXct(July_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(July_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Aug_20 <- mutate(Aug_20,started_at =as.POSIXct(Aug_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Aug_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
sep_20 <- mutate(Sep_20,started_at =as.POSIXct(Sep_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Sep_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Oct_20 <- mutate(Oct_20,started_at =as.POSIXct(Oct_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Oct_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Nov_20 <- mutate(Nov_20,started_at =as.POSIXct(Nov_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Nov_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Dec_20 <- mutate(Dec_20,started_at =as.POSIXct(Dec_20$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Dec_20$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Jan_21 <- mutate(Jan_21,started_at =as.POSIXct(Jan_21$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Jan_21$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Feb_21 <- mutate(Feb_21,started_at =as.POSIXct(Feb_21$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Feb_21$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Mar_21 <- mutate(Mar_21,started_at =as.POSIXct(Mar_21$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Mar_21$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))
Apr_21 <- mutate(Apr_21,started_at =as.POSIXct(Apr_21$started_at,format= "%d-%m-%Y %H:%M",tz="GMT"),ended_at =as.POSIXct(Apr_21$ended_at,format= "%d-%m-%Y %H:%M",tz="GMT"))

# %%
# Removing unwanted columns

Apr_20 <- Apr_20 %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
May_20 <- May_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Jun_20 <- Jun_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
July_20 <- July_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Aug_20 <- Aug_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
sep_20 <- sep_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Oct_20 <- Oct_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Nov_20 <- Nov_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Dec_20 <- Dec_20  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Jan_21 <- Jan_21  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Feb_21 <- Feb_21  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Mar_21 <- Mar_21  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))
Apr_21 <- Apr_21  %>% select(-c(start_station_id,start_station_name,end_station_id,end_station_id))

# %%
# Combining all files  into single Data Frame
all_months <- bind_rows(Apr_20,May_20,Jun_20,July_20,Aug_20,sep_20,Oct_20,Nov_20,Dec_20,Jan_21,Feb_21,Mar_21,Apr_21)
all_months <- all_months_v2

# %%
# Extarcting the month name as label
all_months_v2$month_name_2 <- format(as.Date(all_months$date),abbreviate=FALSE,'%m-%y')

# combining two columns as month_year2
all_months_v2$month_year2 <- paste(all_months_v2$month_name,all_months_v2$year)

# converting numeric month to label
all_months_v2$month_name <- months.POSIXt(all_months_v2$date,abbreviate = FALSE)
#Removing month_name3 column from  all_month_v2
all_months_v2 <- all_months_v2 %>% select(-c(month_name3))

#There are  various trips where ride_length returns a negative duration. These entries need to be omitted from our dataframe
all_months_v2 <- all_months[!(all_months$rideable_type=="docked_bike,electric_bike"|all_months$ride_length<=0),]

# Removing all blank space rows in member_casual column
all_months_v2 <- all_months_v2[!(all_months_v2$member_casual==""),]

# %% [markdown]
# # ANALYSIS AND SHARE

# %%
# postiom= dogde - To create Grouped Bar Chart

all_months_v2 %>% 
  mutate(day_of_week= wday(started_at, label = TRUE)) %>% 
  group_by(member_casual,month,day_of_week) %>% 
  summarise(number_of_rides=n(), mean_duration = mean(ride_length2/60)) %>% 
  arrange(member_casual,day_of_week) %>% 
  ggplot(aes(x=day_of_week, y= mean_duration,fill= member_casual))+ geom_col(position = 'dodge')+
  labs(title = "Average Ride Duration by Day and Rider Type")+ylab("Average Duration (minutes)") + 
  xlab("Day of Week")

# %% [markdown]
# ![Table 2.png](attachment:bd918723-9c26-4334-b8ef-d3da04c381e3.png)

# %% [markdown]
# * Casual riders travel longer than regular membership riders on all weekdays, and casual riders ride more on "Friday"

# %%
# No of rides by day and rider type
   
   all_months_v2 %>% 
     mutate(day_of_week= wday(started_at, label = TRUE)) %>% 
     group_by(day_of_week,member_casual) %>% 
     summarise(number_of_rides=n(), mean_duration = mean(ride_length2/60)) %>% 
     ggplot(aes(x=day_of_week, y= number_of_rides,fill= member_casual))+ geom_col(position = 'dodge')+   labs(title = " Number of Rides by Day and Rider Type") + 
     ylab("Number of Rides(1e+05 = 100,000)") + 
     xlab("Day of Week")

# %% [markdown]
# ![Table 1.png](attachment:83ccc764-930d-48aa-8c10-93a408123f51.png)

# %% [markdown]
# * Annual membership riders take more rides than casual riders other than "Saturday"

# %%
# Number of Rides by Day and Bike Type
all_months_v2 %>% 
     mutate(day_of_week= wday(started_at, label = TRUE)) %>% 
     group_by(day_of_week,rideable_type) %>% 
     summarise(number_of_rides=n(), mean_duration = mean(ride_length2/60)) %>% 
     arrange(rideable_type) %>% 
     ggplot(aes(x=day_of_week, y= number_of_rides,fill= rideable_type))+ geom_col(position = 'dodge')+   labs(title = " Number of Rides by Day and Bike Type") + 
     ylab("Number of Rides(1e+05 = 100,000)") + 
     xlab("Day of Week")

# %% [markdown]
# ![Table 4.png](attachment:4ed8bea4-dc69-438f-8fa2-8a16b2fa8ccd.png)

# %%
 # muatate - Number of Rides by Bike Type and Rider Type
   
   all_months_v2 %>% 
     group_by(member_casual,rideable_type) %>% 
     summarise(number_of_rides=n(), mean_duration = mean(ride_length2)) %>% 
     arrange(member_casual,rideable_type) %>% 
                 ggplot(aes(x=rideable_type, y= number_of_rides,fill= member_casual))+ geom_col(position = 'dodge')+ 
     labs(title = "Number of Rides by Bike Type and Rider Type") +
     ylab("Number of Rides") +  xlab("Bike Type")

# %% [markdown]
# ![Table 3.png](attachment:21683285-7196-41b5-ad6a-26dac34d4a03.png)

# %%
# Number of rides by day and bike type
   ## scael_x_decrete - written to adjust month_year names in order wise
   all_months_v2 %>% 
     group_by(member_casual,month_year2) %>% 
     summarise( number_of_rides=n(),mean_duration = mean(ride_length2)) %>% 
     arrange(month_year2,member_casual) %>% 
     ggplot(aes(x=month_year2, y= number_of_rides ,fill= member_casual))+ geom_col(position = 'dodge')+   labs(title = " Number of Rides by Months and rider Type") + 
     ylab("Number of Rides(1e+05 = 100,000)") +  xlab("Month") +scale_x_discrete(limits=c("April_2020","May_2020","June_2020","July_2020","August_2020","September_2020","October_2020","November_2020","December_2020","January_2021","February_2021","March_2021","April_2021"))+
     theme(axis.text.x = element_text(angle=25))

# %% [markdown]
# ![Table 5.png](attachment:27095fe8-490c-4178-b52b-3fcca43b8fad.png)

# %% [markdown]
# ### Tableu Dashboard

# %% [markdown]
# ![Dashboard 2.png](attachment:52d8e881-9269-48ea-83a1-601e3a9ac61d.png)

# %% [markdown]
# # ACT
# ## Conclusion :
#
# 1. Casual memebers have been using bikes for a long time in all weekdays so converting casual members into annual members is the right decision.  In that case we can create markating statergy that offers discounts  on their ride charge or make them even more enthusiastic like by giving them a free ride (eg; if they complete 10 rides or few kilometers they are eligible for the next 2 or 3 free ride or some specific kilometers)
#
# 2. Annual members take more rides than casual members other than "Saturdays and Sundays" and the number of rides on the weekend is high, so the number of bikes in the top 10 busiest cities on the weekends needs to increase.
#
# 3. The number of rides during the month of " July,August,September" in entire 12 months so high that the bike numbers needs to increase in those months.
#
# 4. Both types of riders ride the "docked bike" 67% so the number of docked bikes needs to be increased
